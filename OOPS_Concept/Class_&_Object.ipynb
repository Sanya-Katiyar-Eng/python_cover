# %% [markdown]
# OOPS Stand for Object oriented programming language.
# mainly work on real-life object
# where object is an instance of realworld and attribute are the properties of object(real-world)
# with the help of oops concept we make our code more eficent or reuseable . and opps concept help to understand realworlds problem
#
# we use like::.....................

# %%
class Class:          #     Creating Class
    def Student(self):  # instance Function
        name=input("ENTER THE NAME : ")
        print(name)

obj=Class() ### creating OBJECT
obj.Student()
# Out:
# SANYA

# %%
class Scholl:
    name="JN Inter Collage" # Class attribute
    def detail(self):
        grade=78
        print(self.name)
        name="patel public" #instance atrribute
        print("class attribute:",self.name)
        print("instance attribute :",name)

o=Scholl()
o.detail()
# Out:
# JN Inter Collage
# class attribute: JN Inter Collage
# instance attribute : patel public

# %% [markdown]
# ### Class Attribute :
# same for each object
# ### Instance Atteibute:
# different for each attribute

# %%
class a:
    def instance(self):
        print("instance method")   #instance method
    @classmethod
    def abc(self,cls):
        print("class method",cls)   # class method
o1=a()
o1.instance()
o1.abc(5)
# Out:
# instance method
# class method 5

# %%
class abc:
    name="Sanya Katiyar"
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def detail(self):
        #age=int(input("enter the age :"))
        print("name : ",self.name,"age : ",self.age)
        course=input("enter course : ")
        print(course)
o=abc("Manya",18)
o.detail()
# Out:
# name :  Manya age :  18
# BCA
